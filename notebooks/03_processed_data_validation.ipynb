# %%
import sys
import importlib
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

import src.validation.data_validation as data_validation

importlib.reload(data_validation)

validate_dataset = data_validation.validate_dataset

# %%
processed_dir = PROJECT_ROOT / "data" / "processed"

validation_df = validate_dataset(processed_dir)

print("Total files:", len(validation_df))
print("Valid files:", validation_df["valid"].sum())
print("Invalid files:", (~validation_df["valid"]).sum())
# Out:
# Found 742 Parquet files
# Validating 1/742: 90044961.parquet
# Validating 2/742: 90045719.parquet
# Validating 3/742: 90047087.parquet
# Validating 4/742: 90047777.parquet
# Validating 5/742: 90048477.parquet
# Validating 6/742: 90049136.parquet
# Validating 7/742: 90049182.parquet
# Validating 8/742: 90049831.parquet
# Validating 9/742: 90050528.parquet
# Validating 10/742: 90050564.parquet
# Validating 11/742: 90051224.parquet
# Validating 12/742: 90051928.parquet
# Validating 13/742: 90052608.parquet
# Validating 14/742: 90053286.parquet
# Validating 15/742: 90053305.parquet
# Validating 16/742: 90053308.parquet
# Validating 17/742: 90053977.parquet
# Validating 18/742: 90054009.parquet
# Validating 19/742: 90054012.parquet
# Validating 20/742: 90054683.parquet
# Validating 21/742: 90054702.parquet
# Validating 22/742: 90054709.parquet
# Validating 23/742: 90055318.parquet
# Validating 24/742: 90055363.parquet
# Validating 25/742: 90055371.parquet
# ...

# %%
import sys
import importlib
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

import src.validation.data_validation as data_validation

importlib.reload(data_validation)

validate_dataset = data_validation.validate_dataset

# %%
processed_v2_dir = PROJECT_ROOT / "data" / "processed_v2"

validation_v2_df = validate_dataset(
    processed_v2_dir
)
# Out:
# Found 742 Parquet files
# Validating 1/742: 90044961.parquet
# Validating 2/742: 90045719.parquet
# Validating 3/742: 90047087.parquet
# Validating 4/742: 90047777.parquet
# Validating 5/742: 90048477.parquet
# Validating 6/742: 90049136.parquet
# Validating 7/742: 90049182.parquet
# Validating 8/742: 90049831.parquet
# Validating 9/742: 90050528.parquet
# Validating 10/742: 90050564.parquet
# Validating 11/742: 90051224.parquet
# Validating 12/742: 90051928.parquet
# Validating 13/742: 90052608.parquet
# Validating 14/742: 90053286.parquet
# Validating 15/742: 90053305.parquet
# Validating 16/742: 90053308.parquet
# Validating 17/742: 90053977.parquet
# Validating 18/742: 90054009.parquet
# Validating 19/742: 90054012.parquet
# Validating 20/742: 90054683.parquet
# Validating 21/742: 90054702.parquet
# Validating 22/742: 90054709.parquet
# Validating 23/742: 90055318.parquet
# Validating 24/742: 90055363.parquet
# Validating 25/742: 90055371.parquet
# ...

# %%
print("Total files:", len(validation_v2_df))
print("Valid files:", validation_v2_df["valid"].sum())
print("Invalid files:", (~validation_v2_df["valid"]).sum())
# Out:
# Total files: 742
# Valid files: 742
# Invalid files: 0
